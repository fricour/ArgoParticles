# %%
import pandas as pd

# %%
tmp = pd.read_parquet('../../dist/_file/s3-particle_size_spectra.48550bfc.parquet')

# %%
tmp.wmo.unique()
# Out:
# array([1902578, 6990503])

# %%
tmp
# Out:
#            wmo  cycle  park_depth                          juld  mean_slope  \
# 0      1902578      1        1000 2022-05-29 19:04:15.000000000   -2.748985
# 1      1902578      1        1000 2022-05-29 21:04:14.000000000   -2.560807
# 2      1902578      1        1000 2022-05-29 23:04:13.999999744   -4.338853
# 3      1902578      1        1000 2022-05-30 01:04:15.000000000   -2.410774
# 4      1902578      2        1000 2022-05-30 13:59:51.000000000   -2.844171
# ...        ...    ...         ...                           ...         ...
# 24234  6990503    133         200 2025-10-09 10:01:51.000000000   -2.220192
# 24235  6990503    133         200 2025-10-09 10:21:51.000000000   -2.937290
# 24236  6990503    133         200 2025-10-09 10:41:51.000000000   -2.598726
# 24237  6990503    133         200 2025-10-09 11:01:51.000000000   -2.587943
# 24238  6990503    133         500 2025-10-09 14:10:12.000000000   -3.377443
#
#                         zone
# ...
